# %%
import os

# %%
with open("filenames_temp.txt", "r") as test:
    filenames = test.readlines()

filenames
# Out:
# ['.dockerignore\n',
#  '.dvc/.gitignore\n',
#  '.dvc/config\n',
#  '.dvcignore\n',
#  '.github/workflows/run_experiment.yml\n',
#  '.gitignore\n',
#  'Dockerfile\n',
#  'README.md\n',
#  'alg/NSGA_II/__init__.py\n',
#  'alg/NSGA_II/analyze_populations.py\n',
#  'alg/NSGA_II/base_nsga_ii.py\n',
#  'alg/NSGA_II/conf/experiment/basic.yaml\n',
#  'alg/NSGA_II/conf/experiment_1.yaml\n',
#  'alg/NSGA_II/conf/experiment_1_base.yaml\n',
#  'alg/NSGA_II/conf/experiment_1_hash_base.yaml\n',
#  'alg/NSGA_II/conf/experiment_1_hash_restricted.yaml\n',
#  'alg/NSGA_II/conf/experiment_1_restricted_pos.yaml\n',
#  'alg/NSGA_II/conf/experiment_classical.yaml\n',
#  'alg/NSGA_II/conf/experiment_classical_test.yaml\n',
#  'alg/NSGA_II/conf/experiment_qga_position.yaml\n',
#  'alg/NSGA_II/conf/qmea/hash_multiset.yaml\n',
#  'alg/NSGA_II/conf/qmea/hash_permutation.yaml\n',
#  'alg/NSGA_II/conf/qmea/position_multiset.yaml\n',
#  'alg/NSGA_II/conf/qmea/position_permutation.yaml\n',
# ...

# %%
for cur_filename in filenames:
    file_stats = os.stat(cur_filename[:-1])
    print(cur_filename[:-1] + ": " + str(os.path.exists(cur_filename[:-1])) + " - size: " + str(file_stats.st_size / (1024)**2))
# Out:
# .dockerignore: True - size: 0.0006875991821289062
# .dvc/.gitignore: True - size: 2.765655517578125e-05
# .dvc/config: True - size: 0.00018310546875
# .dvcignore: True - size: 0.00018978118896484375
# .github/workflows/run_experiment.yml: True - size: 0.00087738037109375
# .gitignore: True - size: 0.003177642822265625
# Dockerfile: True - size: 0.0019006729125976562
# README.md: True - size: 0.0014448165893554688
# alg/NSGA_II/__init__.py: True - size: 0.0
# alg/NSGA_II/analyze_populations.py: True - size: 0.010782241821289062
# alg/NSGA_II/base_nsga_ii.py: True - size: 0.009814262390136719
# alg/NSGA_II/conf/experiment/basic.yaml: True - size: 0.00029754638671875
# alg/NSGA_II/conf/experiment_1.yaml: True - size: 0.003452301025390625
# alg/NSGA_II/conf/experiment_1_base.yaml: True - size: 0.00072479248046875
# alg/NSGA_II/conf/experiment_1_hash_base.yaml: True - size: 0.0009260177612304688
# alg/NSGA_II/conf/experiment_1_hash_restricted.yaml: True - size: 0.0007915496826171875
# ...

# %%
os.path.exists(".dockerignore")
# Out:
# True

# %%
cur_filename[:-2]
# Out:
# 'testcp'
